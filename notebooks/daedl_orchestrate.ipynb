# %% [markdown]
# # DAEDL Orchestration
#
# This notebook is intentionally thin. The implementation lives in `src/daedl/`; this file only configures and runs training/evaluation.

# %%
from pathlib import Path
import sys

# Colab users can uncomment these lines:
# from google.colab import drive
# drive.mount('/content/drive')
# REPO_ROOT = Path('/content/drive/MyDrive/EpistemicRanker')

REPO_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

print(f'Repo root: {REPO_ROOT}')

# %%
from src.daedl import DAEDLConfig, orchestrate

config = DAEDLConfig(
    project_root=REPO_ROOT,
    batch_size=128,
    train_num_workers=0,
    train_persistent_workers=False,
    use_local_processed=True,
)

config

# %%
run = orchestrate(config, run_train=True, run_eval=True)
results = run['results']
results
